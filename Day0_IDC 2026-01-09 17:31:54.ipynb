# %%
# !pip install kaggle

# %%
import os

os.environ["KAGGLE_USERNAME"] = "gantasagarika"
os.environ["KAGGLE_KEY"] = "a3d9c4991cd557aa5e3f7275257c9be9"

print("Kaggle credentials configured!")

# %%
spark.sql("""
CREATE SCHEMA IF NOT EXISTS workspace.ecommerce
""")

# %%
spark.sql("""
CREATE VOLUME IF NOT EXISTS workspace.ecommerce.ecommerce_data
""")

# %%
cd /Volumes/workspace/ecommerce/ecommerce_data kaggle datasets download -d mkechinov/ecommerce-behavior-data-from-multi-category-store

# %%
# !mkdir -p /Volumes/workspace/ecommerce/ecommerce_data

# %%
# %cd /Volumes/workspace/ecommerce/ecommerce_data

# %%
# !kaggle datasets download -d mkechinov/ecommerce-behavior-data-from-multi-category-store

# %%
# !unzip ecommerce-behavior-data-from-multi-category-store.zip

# %%
ls -lh

# %%
# !unzip ecommerce-behavior-data-from-multi-category-store.zip

# %%
# !ls -lh

# %%
# %sh
cd /Volumes/workspace/ecommerce/ecommerce_data
rm -f ecommerce-behavior-data-from-multi-category-store.zip
ls -lh

# %%
# %restart_python

# %%
df_n = spark.read.csv("/Volumes/workspace/ecommerce/ecommerce_data/2019-Nov.csv")

# %%
df = spark.read.csv("/Volumes/workspace/ecommerce/ecommerce_data/2019-Oct.csv")

# %%
print(f"October 2019 - Total Events: {df.count():,}")
print("\n" + "="*60)
print("SCHEMA:")
print("="*60)
df.printSchema()

# %%
print("\n" + "="*60)
print("SAMPLE DATA (First 5 rows):")
print("="*60)
df.show(5, truncate=False)

# %%
# Load your data
events = spark.read.format("parquet").load(
    "/Volumes/workspace/ecommerce/ecommerce_data/Oct"
)

# Verify it's working
print(f"✅ Ready to go! Loaded {events.count():,} events")
events.show(5)

# Your Day 1 challenges start here...

# %%
# Load your data
events = spark.read.csv(
    "/Volumes/workspace/ecommerce/ecommerce_data/2019-Oct.csv",
    header=True,
    inferSchema=True
)

# Verify it's working
print(f"✅ Ready to go! Loaded {events.count():,} events")
events.show(5)

# Your Day 1 challenges start here...
